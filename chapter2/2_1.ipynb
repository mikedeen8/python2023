# %% [markdown]
# # Задание 2_1
#
# Тест, специально делаю ошибки + кто-то сделал график функции(зачем-то).

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.linspace(-2, 2, 10000)

y = x**2
z = 2*x - 1

plt.plot(x, y)
plt.plot(x, z)
plt.grid(color='r', linestyle='-', linewidth=0.5)


plt.show()

# %%
42 = n
# Out:
#   Cell In[20], line 1
#     42 = n
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
x = y = 1

# %%
print(1);
print(2)
# Out:
# 1
# 2

# %%
print(1)
print(2).
# Out:
#   Cell In[23], line 2
#     print(2).
#              ^
# SyntaxError: invalid syntax

# %%
x = 0
y = 1
print(xy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 x = 0
#       2 y = 1
# ----> 3 print(xy)
#
# NameError: name 'xy' is not defined
